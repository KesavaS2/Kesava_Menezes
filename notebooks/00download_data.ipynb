# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/KesavaS2/Kesava_Menezes/master/data/raw/sleep_efficiency.csv")
df.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# ...

# %%
df.to_csv("../data/raw/sleep_efficiency.csv",index=False)

# %%
dicionario = pd.DataFrame ([
{
"variavel": "ID",
"descrição": " Identificador único do indivíduo",
"tipo": "qualitativa",
"subtipo": "nominal"
},{
"variavel": "Age",
"descrição": " Idade do indivíduo em anos.",
"tipo": "quantitativa",
"subtipo": "discreta"
},{
"variavel": "Gender",
"descrição": " Gênero do indivíduo.",
"tipo": "qualitativa",
"subtipo": "nominal"
},{
"variavel": "Bedtime",
"descrição": "Hora em que o indivíduo foi para a cama. Formato de data e hora: YYYY-MM-DD HH:MM",
"tipo": "qualitativa",
"subtipo": "nominal"
},{
"variavel": " Wakeup time",
"descrição": "Hora em que o indivíduo acordou. Formato de data e hora: YYYY-MM-DD HH:MM",
"tipo": "qualitativa",
"subtipo": "nominal"
},{
"variavel": " Sleep duration",
"descrição": "Duração total do sono do indivíduo em horas",
"tipo": "quantitativa",
"subtipo": "contínua"
},{
"variavel": " Sleep efficiency",
"descrição": "Eficiência do sono do indivíduo",
"tipo": "quantitativa",
"subtipo": "contínua"
},{
"variavel": "REM sleep percentage",
"descrição": "Percentual de sono REM (Rapid Eye Movement) do indivíduo em relação ao tempo total de sono",
"tipo": "quantitativa",
"subtipo": "discreta"
},{
"variavel": " Deep sleep percentage",
"descrição": "Percentual de sono profundo do indivíduo em relação ao tempo total de sono",
"tipo": "quantitativa",
"subtipo": "discreta"
},{
"variavel": " Light sleep percentage",
"descrição": "Percentual de sono leve do indivíduo em relação ao tempo total de sono.",
"tipo": "quantitativa",
"subtipo": "discreta"
},{
"variavel": " Awakenings",
"descrição": "Número de vezes que o indivíduo despertou durante o período de sono",
"tipo": "quantitativa",
"subtipo": "discreta"
},{
"variavel": " Caffeine consumption",
"descrição": "Quantidade de cafeína consumida pelo indivíduo em miligramas (mg) durante o dia",
"tipo": "quantitativa",
"subtipo": "contínua"
},{
"variavel": " Alcohol consumption",
"descrição": "Quantidade de álcool consumida pelo indivíduo em gramas (g) durante o dia",
"tipo": "quantitativa",
"subtipo": "contínua"
},{
"variavel": " Smoking status",
"descrição": "Status de fumante do indivíduo. Possíveis valores incluem Yes (Sim) e No (Não)",
"tipo": "qualitativa",
"subtipo": "nominal"
},{
"variavel": " Exercise frequency",
"descrição": "Frequência com que o indivíduo pratica exercícios físicos durante a semana",
"tipo": "quantitativa",
"subtipo": "discreta"
}
])

# %%
dicionario.to_csv("../data/external/dictionary.csv",index=False)

# %%
dicionario
# Out:
#                    variavel  \
# 0                        ID
# 1                       Age
# 2                    Gender
# 3                   Bedtime
# 4               Wakeup time
# 5            Sleep duration
# 6          Sleep efficiency
# 7      REM sleep percentage
# 8     Deep sleep percentage
# 9    Light sleep percentage
# 10               Awakenings
# 11     Caffeine consumption
# 12      Alcohol consumption
# 13           Smoking status
# 14       Exercise frequency
#
#                                             descrição          tipo   subtipo
# 0                    Identificador único do indivíduo   qualitativa   nominal
# 1                         Idade do indivíduo em anos.  quantitativa  discreta
# 2                                Gênero do indivíduo.   qualitativa   nominal
# 3   Hora em que o indivíduo foi para a cama. Forma...   qualitativa   nominal
# 4   Hora em que o indivíduo acordou. Formato de da...   qualitativa   nominal
# ...
